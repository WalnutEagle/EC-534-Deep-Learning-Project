# %%
import shutil
shutil.rmtree('/content/drive', ignore_errors=True)

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# Define paths
input_dir = "/content/drive/My Drive/data/Task06_Lung/Task06_Lung/imagesTS_png"  # Path to PNG slices
output_dir = "/content/drive/My Drive/data/Task06_Lung/Task06_Lung/output"       # Directory for enhanced output
checkpoint_path = "/content/drive/My Drive/data/checkpoints/ckpt/CT.pt"         # Path to pre-trained weights

# Create output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Check paths
print(f"Input Directory: {input_dir}")
print(f"Output Directory: {output_dir}")
print(f"Checkpoint Path: {checkpoint_path}")
# Out:
# Input Directory: /content/drive/My Drive/data/Task06_Lung/Task06_Lung/imagesTS_png
# Output Directory: /content/drive/My Drive/data/Task06_Lung/Task06_Lung/output
# Checkpoint Path: /content/drive/My Drive/data/checkpoints/ckpt/CT.pt

# %%
# !git clone https://github.com/bowang-lab/DPM-MedImgEnhance.git
# %cd DPM-MedImgEnhance
# Out:
# Cloning into 'DPM-MedImgEnhance'...
# remote: Enumerating objects: 34, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 34 (delta 7), reused 26 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (34/34), 48.89 KiB | 794.00 KiB/s, done.
# Resolving deltas: 100% (7/7), done.
# /content/DPM-MedImgEnhance

# %%
import os
checkpoint_dir = "/content/drive/My Drive/data/checkpoints/ckpt"
print(os.listdir(checkpoint_dir))
# Out:
# ['MR.pt', 'CT.pt']

# %%
# !python CT_main.py \
    --config config.yml \
    --deg denoising \
    --deg_scale 1.0 \
    -i "/content/drive/My Drive/data/Task06_Lung/Task06_Lung/imagesTS_png" \
    -o "/content/drive/My Drive/data/Task06_Lung/Task06_Lung/output" \
    --model_path "/content/drive/My Drive/data/checkpoints/ckpt/CT.pt" \
    --seed 42 \
    --eta 0
# Out:
# Streaming output truncated to the last 5000 lines.
#  15% 15/100 [00:00<00:04, 21.20it/s]
#  18% 18/100 [00:00<00:03, 21.14it/s]
#  21% 21/100 [00:00<00:03, 21.08it/s]
#  24% 24/100 [00:01<00:03, 20.93it/s]
#  27% 27/100 [00:01<00:03, 21.12it/s]
#  30% 30/100 [00:01<00:03, 21.08it/s]
#  33% 33/100 [00:01<00:03, 21.17it/s]
#  36% 36/100 [00:01<00:03, 21.18it/s]
#  39% 39/100 [00:01<00:02, 21.16it/s]
#  42% 42/100 [00:01<00:02, 21.05it/s]
#  45% 45/100 [00:02<00:02, 20.98it/s]
#  48% 48/100 [00:02<00:02, 21.07it/s]
#  51% 51/100 [00:02<00:02, 21.04it/s]
#  54% 54/100 [00:02<00:02, 21.11it/s]
#  57% 57/100 [00:02<00:02, 21.17it/s]
#  60% 60/100 [00:02<00:01, 21.20it/s]
#  63% 63/100 [00:02<00:01, 21.24it/s]
#  66% 66/100 [00:03<00:01, 21.18it/s]
#  69% 69/100 [00:03<00:01, 21.19it/s]
#  72% 72/100 [00:03<00:01, 21.26it/s]
#  75% 75/100 [00:03<00:01, 21.28it/s]
#  78% 78/100 [00:03<00:01, 21.33it/s]
#  81% 81/100 [00:03<00:00, 21.32it/s]
#  84% 84/100 [00:03<00:00, 21.31it/s]
# ...
